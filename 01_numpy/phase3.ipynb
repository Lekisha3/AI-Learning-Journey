# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Data structure : [restaurant_id , 2021,2022,2023,2024]
sales_data = np.array([
    [1,150000,180000,220000,250000],    # Paradise Biryani
    [2,120000,140000,160000,190000],    #Beijing Bites
    [3,200000,230000,260000,300000],    # Pizza Hub
    [4,180000,210000,240000,270000],    # Burgur Point
    [5,160000,185000,205000,230000]     #Chai point
    
])

print("==== Zomato sales analysis ====")
print("sales data shape ",sales_data.shape)
print("sample data for 1st 3 restaurant",sales_data[0:3])
print("sample data for 1st 3 restaurant",sales_data[:3])
print("sample data for 1st 3 restaurant",sales_data[: ,1:])
print("sample data for 1st 3 restaurant",sales_data[:,:3])
print("\n all restaurant 2024 data \n ",sales_data[:,4])
print("sample data for 1st 3 restaurant",sales_data[1,4])
# Out:
# ==== Zomato sales analysis ====
# sales data shape  (5, 5)
# sample data for 1st 3 restaurant [[     1 150000 180000 220000 250000]
#  [     2 120000 140000 160000 190000]
#  [     3 200000 230000 260000 300000]]
# sample data for 1st 3 restaurant [[     1 150000 180000 220000 250000]
#  [     2 120000 140000 160000 190000]
#  [     3 200000 230000 260000 300000]]
# sample data for 1st 3 restaurant [[150000 180000 220000 250000]
#  [120000 140000 160000 190000]
#  [200000 230000 260000 300000]
#  [180000 210000 240000 270000]
#  [160000 185000 205000 230000]]
# sample data for 1st 3 restaurant [[     1 150000 180000]
#  [     2 120000 140000]
#  [     3 200000 230000]
#  [     4 180000 210000]
#  [     5 160000 185000]]
#
#  all restaurant 2024 data
#   [250000 190000 300000 270000 230000]
# sample data for 1st 3 restaurant 190000

# %%
# total sales per year
print(np.sum(sales_data,axis=0))

#yearly total
print(np.sum(sales_data[:,1:],axis=0))

print(np.sum(sales_data[:,1:],axis=1))

#minimum sales per restaurant
min_sales=np.min(sales_data[:,1:],axis=1)
print(min_sales)

#Maximum sales per year
max_sales=np.max(sales_data[:,1:],axis=0)
print(max_sales)

#average sales per restaurant
avg_sales = np.average(sales_data[:,1:],axis=1)
print(avg_sales)

avg_sales = np.mean(sales_data[:,1:],axis=1)
print(avg_sales)

#cumulative sales 
cumsum=np.cumsum(sales_data[:,1:],axis=1)
print( "\n",cumsum)

plt.figure(figsize=(10,6))
plt.plot(np.mean(cumsum,axis=0))
plt.title("Average cumulative sales across all restaurant")
plt.xlabel("Years")
plt.ylabel("sales")
plt.grid(True)
plt.show()
# Out:
# [     15  810000  945000 1085000 1240000]
# [ 810000  945000 1085000 1240000]
# [800000 610000 990000 900000 780000]
# [150000 120000 200000 180000 160000]
# [200000 230000 260000 300000]
# [200000. 152500. 247500. 225000. 195000.]
# [200000. 152500. 247500. 225000. 195000.]
#
#  [[150000 330000 550000 800000]
#  [120000 260000 420000 610000]
#  [200000 430000 690000 990000]
#  [180000 390000 630000 900000]
#  [160000 345000 550000 780000]]

# %%
#vector operations 
vector1 = np.array([1,2,3,4,5])
vector2=np.array([6,7,8,9,10])

print("vector addition " , vector1+vector2)
print("multiplication of vector " , vector1*vector2)
print("multiplication of vector " , vector2*vector1)

print("Dot product", np.dot(vector1,vector2))

angle= np.arccos(np.dot(vector1,vector2)/ (np.linalg.norm(vector1)*(np.linalg.norm(vector2))))
print("\n ",angle)
# Out:
# vector addition  [ 7  9 11 13 15]
# multiplication of vector  [ 6 14 24 36 50]
# multiplication of vector  [ 6 14 24 36 50]
# Dot product 130
#
#   0.26554161733900966

# %%
# vectorized operation (har ek ke sath activity perform kr sakta hai )
restaurant_types= np.array(["biryani","pizza","burger","poha"])
vectorized_upper=np.vectorize(str.upper)
print("vectorized upper",vectorized_upper(restaurant_types))
# Out:
# vectorized upper ['BIRYANI' 'PIZZA' 'BURGER' 'POHA']

# %%
#Broadcaste
monthly_avg=sales_data[:,1:]/12
print(monthly_avg)
# Out:
# [[12500.         15000.         18333.33333333 20833.33333333]
#  [10000.         11666.66666667 13333.33333333 15833.33333333]
#  [16666.66666667 19166.66666667 21666.66666667 25000.        ]
#  [15000.         17500.         20000.         22500.        ]
#  [13333.33333333 15416.66666667 17083.33333333 19166.66666667]]
